# %% [markdown]
# # The Sparks Foundation Graduate Rotational Internship Program(Function: Data Science and Business Analytics)
#
# ## Prepared by- Darsh Shah
#
# ## Task-2: Prediction using Decision Tree Algorithm
#
# ## Statement: Create a Decision tree classifier and visualize it graphically for a given dataset

# %% [markdown]
# ## Step-1: Importing the libraries

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn import metrics

# %% [markdown]
# ## Step-2: Loading and summarizing the dataset

# %%
url="C:/Users/darsh/Downloads/Iris.csv"
df=pd.read_csv(url)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ## Step-3: Cleaning the data

# %%
df.drop("Id",axis=1,inplace=True)

# %% [markdown]
# ## Step-4: Separating dependent and independent variables

# %%
x=df.drop("Species",axis=1)
y=df["Species"]
y=pd.DataFrame(y)

# %% [markdown]
# ## Step-5: Label Encoding the data

# %%
le_species=LabelEncoder()
y["Species1"]=le_species.fit_transform(y["Species"])
y.drop("Species",axis=1,inplace=True)

# %%
print(y)
# Out:
#      Species1
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 145         2
# 146         2
# 147         2
# 148         2
# 149         2
#
# [150 rows x 1 columns]

# %% [markdown]
# ## Step-6: Splitting the data for training and testing of model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5)

# %% [markdown]
# ## Step-7: Training the model

# %%
model=tree.DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Step-8: Predicting the data

# %%
y_pred=model.predict(x_test)

# %% [markdown]
# ## Step-9: Checking the efficiency of our model

# %%
print(metrics.mean_absolute_error(y_test,y_pred))
# Out:
# 0.13333333333333333

# %% [markdown]
# ## Step-10: Visualizing the Decision Tree

# %%
plt.figure(figsize=(14,9))
tree.plot_tree(model,filled=True)
# Out:
# [Text(312.48, 454.2942857142857, 'X[2] <= 2.45\ngini = 0.666\nsamples = 120\nvalue = [42, 39, 39]'),
#  Text(156.24, 384.40285714285716, 'gini = 0.0\nsamples = 42\nvalue = [42, 0, 0]'),
#  Text(468.72, 384.40285714285716, 'X[3] <= 1.75\ngini = 0.5\nsamples = 78\nvalue = [0, 39, 39]'),
#  Text(312.48, 314.51142857142855, 'X[0] <= 4.95\ngini = 0.133\nsamples = 42\nvalue = [0, 39, 3]'),
#  Text(156.24, 244.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(468.72, 244.62, 'X[0] <= 7.1\ngini = 0.093\nsamples = 41\nvalue = [0, 39, 2]'),
#  Text(312.48, 174.7285714285714, 'X[2] <= 4.95\ngini = 0.049\nsamples = 40\nvalue = [0, 39, 1]'),
#  Text(156.24, 104.83714285714285, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(468.72, 104.83714285714285, 'X[1] <= 2.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(312.48, 34.945714285714246, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(624.96, 34.945714285714246, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
# ...

# %%
print(tree.export_text(model))
# Out:
# |--- feature_2 <= 2.45
# |   |--- class: 0
# |--- feature_2 >  2.45
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_0 <= 4.95
# |   |   |   |--- class: 2
# |   |   |--- feature_0 >  4.95
# |   |   |   |--- feature_0 <= 7.10
# |   |   |   |   |--- feature_2 <= 4.95
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  4.95
# |   |   |   |   |   |--- feature_1 <= 2.45
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- feature_1 >  2.45
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  7.10
# |   |   |   |   |--- class: 2
# |   |--- feature_3 >  1.75
# |   |   |--- class: 2

# %%
model.predict([[4.6,3.1,1.5,0.]])
# Out:
# array([0])
